# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import pandas as pd
import os

# %%
#load model and tokenizer
model_path = os.path.join('..', 'ml_settings', 'toxicity_small_rnn.h5')
tokenizer_path = os.path.join('..', 'ml_settings', 'toxicity_small_tokenizer')
model = tf.keras.models.load_model(model_path)
tokenizer = tfds.features.text.SubwordTextEncoder.load_from_file(tokenizer_path)

# %%
csv_path = os.path.join('..', 'Data', 'political_ads_20200502')
df = pd.read_csv(csv_path)
df.head()
# Out:
#    Unnamed: 0            Ad ID  \
# 0           0  161547868597338
# 1           1  220048305965126
# 2           2  226523441965853
# 3           3  226976695231799
# 4           4  230613321597608
#
#                                               Ad URL            Ad Text  \
# 0  https://www.facebook.com/ads/archive/render_ad...  {{product.brand}}
# 1  https://www.facebook.com/ads/archive/render_ad...  {{product.brand}}
# 2  https://www.facebook.com/ads/archive/render_ad...  {{product.brand}}
# 3  https://www.facebook.com/ads/archive/render_ad...  {{product.brand}}
# 4  https://www.facebook.com/ads/archive/render_ad...  {{product.brand}}
#
#              Hosted Page                                     Impressions  \
# 0  Vote Yes for Fair Tax  {'lower_bound': '1000', 'upper_bound': '1999'}
# 1  Vote Yes for Fair Tax  {'lower_bound': '5000', 'upper_bound': '5999'}
# 2  Vote Yes for Fair Tax  {'lower_bound': '6000', 'upper_bound': '6999'}
# ...

# %%
# function for padding out an input string with 0s
def pad_to_size(vec, size):
  zeros = [0] * (size - len(vec))
  vec.extend(zeros)
  return vec

# create a function for predicting toxicity from a string. Add token padding by default
def sample_predict(sample_pred_text, pad=True):
  encoded_sample_pred_text = tokenizer.encode(sample_pred_text)

  if pad:
    encoded_sample_pred_text = pad_to_size(encoded_sample_pred_text, 64) # call pad_to_size to be at least 64 dimensions long
  encoded_sample_pred_text = tf.cast(encoded_sample_pred_text, tf.float32)
  predictions = model.predict(tf.expand_dims(encoded_sample_pred_text, 0))

  return (predictions)

#set function for analyzing text toxicity
def find_toxicity(tox_prob):
    if tox_prob >= 0.5:
        return True
    return False#set function for analyzing text toxicity
def find_toxicity(tox_prob):
    if tox_prob >= 0.5:
        return True
    return False

# %%
sample_predict('fuck you you stupid asshole')
# Out:
# array([[1.7779737]], dtype=float32)

# %%
test = sample_predict('fuck you you fucking fuck')
find_toxicity(test)
# Out:
# True

# %%
toxicity_list = []
for entry in df['Ad Text']:
    prob = sample_predict(str(entry))
    tox = find_toxicity(prob)
    toxicity_list.append(tox)
df['Toxicity'] = toxicity_list
df.head()
# Out:
# WARNING:tensorflow:5 out of the last 25 calls to <function _make_execution_function.<locals>.distributed_function at 0x149ed3730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# ...

# %%
toxicity_list
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...
